# %% [markdown]
# # Introduction
#
# In the pursuit of academic excellence, understanding the factors that contribute to students achieving a first-class distinction is crucial. This grade analysis aims to uncover the key elements that differentiate students who consistently attain first-class honors, providing valuable insights for optimizing educational practices.

# %% [markdown]
# # Problem Statement
#
# The primary focus of this study is to identify the determinants leading to students consistently achieving first-class distinctions. By examining factors such as course of study, year of study, marital status among others, we aim to provide actionable insights for educators and policymakers to enhance overall academic performance.

# %% [markdown]
# # 📗 Imports

# %%
#importing libraries
import pandas as pd #For processing and cleaning

#imports for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# # 👓Data Inspection

# %%
#View the number of rows and columns

df.shape
# Out:
# (101, 11)

# %%
#first five records

df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
#last five records

df.tail()
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 96                      year 1        3.50 - 4.00             No
# 97                      Year 2        3.00 - 3.49             No
# 98                      Year 3        3.50 - 4.00            Yes
# 99                      year 4        3.50 - 4.00             No
# 100                     Year 2        3.00 - 3.49             No
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %%
#duplicate value inspection

df.duplicated().sum()
# Out:
# 0

# %%
#inspection of null values

df.isna().sum()
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             1
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %%
#view the values in the course columns

df.iloc[:,3].unique()
# Out:
# array(['Engineering', 'Islamic education', 'BIT', 'Laws', 'Mathemathics',
#        'Pendidikan islam', 'BCS', 'Human Resources', 'Irkhs',
#        'Psychology', 'KENMS', 'Accounting ', 'ENM', 'Marine science',
#        'KOE', 'Banking Studies', 'Business Administration', 'Law',
#        'KIRKHS', 'Usuluddin ', 'TAASL', 'Engine', 'ALA',
#        'Biomedical science', 'koe', 'Kirkhs', 'BENL', 'Benl', 'IT', 'CTS',
#        'engin', 'Econs', 'MHSC', 'Malcom', 'Kop', 'Human Sciences ',
#        'Biotechnology', 'Communication ', 'Diploma Nursing',
#        'Pendidikan Islam ', 'Radiography', 'psychology', 'Fiqh fatwa ',
#        'DIPLOMA TESL', 'Koe', 'Fiqh', 'Islamic Education', 'Nursing ',
#        'Pendidikan Islam'], dtype=object)

# %%
#view the values in the year of study columns

df.iloc[:,4].unique()
# Out:
# array(['year 1', 'year 2', 'Year 1', 'year 3', 'year 4', 'Year 2',
#        'Year 3'], dtype=object)

# %% [markdown]
# > # Variable Description
#
# * **Timestamp**: This column likely records the date and time when the survey or data entry was completed. It helps in tracking when each record was added to the dataset.
#
# * **Choose your gender**: This column captures the gender information of the students.
#
# * **Age**: This column contains the age of each student. It provides information about the age distribution of the surveyed students.
#
# * **What is your course?**: This column likely represents the academic program or course that the student is enrolled in. It provides insights into the diversity of academic disciplines among the respondents.
#
# * **Your current year of Study**: This column indicates the current academic year or level of study that the student is in (e.g., year1, year2, etc.).
#
# * **What is your CGPA?**: This column holds information about the Cumulative Grade Point Average (CGPA) of the students. It gives an idea of the academic performance of the respondents.
#
# * **Marital status**: This is a binary column which captures the marital status of the students, indicating whether they are single or married.
#
# * **Do you have Depression?**: This is a binary column, likely representing whether or not the student self-reports experiencing depression.
#
# * **Do you have Anxiety?**: Similar to the previous column, this binary column indicates whether or not the student self-reports experiencing anxiety.
#
# * **Do you have Panic attack?**: This column is also binary, likely indicating whether or not the student experiences panic attacks.
#
# * **Did you seek any specialist for a treatment?**: This column likely records whether the students sought help from a specialist or professional for the mental health issues other than depression, anxiety, or panic attacks.

# %%
#Statistical info of the data

df.describe()
# Out:
#              Age
# count  100.00000
# mean    20.53000
# std      2.49628
# min     18.00000
# 25%     18.00000
# 50%     19.00000
# 75%     23.00000
# max     24.00000

# %%
#Summarized information of the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Timestamp                                     101 non-null    object
#  1   Choose your gender                            101 non-null    object
#  2   Age                                           100 non-null    float64
#  3   What is your course?                          101 non-null    object
#  4   Your current year of Study                    101 non-null    object
#  5   What is your CGPA?                            101 non-null    object
#  6   Marital status                                101 non-null    object
#  7   Do you have Depression?                       101 non-null    object
#  8   Do you have Anxiety?                          101 non-null    object
# ...

# %% [markdown]
# >After thoroughly inspecting the data, I've identified 11 columns and 101 records with no duplicates or null values. To enhance accessibility, I'll simplify column names. Regarding the 'Timestamp' column, I'll retain only the date and convert its data type to datetime, as time details are unnecessary for our analysis.
# >
# >Additionally, I noticed that the 'Age' columns are in float; I'll convert them to integers for precision. There are conflicting keys in the 'Year of Study' columns ('Year 1' and 'year 1'), which I'll standardize using the lower function.
# >
# >Furthermore, in the 'CGPA' column, the range 3.50 - 4.00 occurs twice and some values in the course column appear more than once. I'll address this duplication during the data cleaning phase. These steps aim to streamline our dataset for a smoother analysis.

# %% [markdown]
# # 🧹 Data Cleaning

# %%
#new columns

new_columns = ["time_stamp","gender","age","course","current_year","cgpa","married","depression","anxiety","panic_attack","specialist_treatment"]

# %%
#Set the new columns

df.columns = new_columns

# %%
#view the changes in the dataframe

df
# Out:
#               time_stamp  gender   age              course current_year  \
# 0         8/7/2020 12:02  Female  18.0         Engineering       year 1
# 1         8/7/2020 12:04    Male  21.0   Islamic education       year 2
# 2         8/7/2020 12:05    Male  19.0                 BIT       Year 1
# 3         8/7/2020 12:06  Female  22.0                Laws       year 3
# 4         8/7/2020 12:13    Male  23.0        Mathemathics       year 4
# ..                   ...     ...   ...                 ...          ...
# 96   13/07/2020 19:56:49  Female  21.0                 BCS       year 1
# 97   13/07/2020 21:21:42    Male  18.0         Engineering       Year 2
# 98   13/07/2020 21:22:56  Female  19.0            Nursing        Year 3
# 99   13/07/2020 21:23:57  Female  23.0    Pendidikan Islam       year 4
# 100  18/07/2020 20:16:21    Male  20.0  Biomedical science       Year 2
#
#             cgpa married depression anxiety panic_attack specialist_treatment
# ...

# %%
#Function to edit the time stamp

def clean(time_stamp):
   return time_stamp.split(" ")[0]

# %%
#Apply the function

df.time_stamp = df.time_stamp.apply(clean)

# %%
#Convert the datatype

df.time_stamp = pd.to_datetime(df.time_stamp)
# Out:
# C:\Users\BJ-Kings\AppData\Local\Temp\ipykernel_2896\1685773611.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.time_stamp = pd.to_datetime(df.time_stamp)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   time_stamp            101 non-null    datetime64[ns]
#  1   gender                101 non-null    object
#  2   age                   100 non-null    float64
#  3   course                101 non-null    object
#  4   current_year          101 non-null    object
#  5   cgpa                  101 non-null    object
#  6   married               101 non-null    object
#  7   depression            101 non-null    object
#  8   anxiety               101 non-null    object
#  9   panic_attack          101 non-null    object
#  10  specialist_treatment  101 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 8.8+ KB

# %%
#Edit the time column to have the same format

def clean(date):
    return date.strftime('%d-%B-%Y').split("-")[1]

# %%
#create the month column

df['month_filled'] = df.time_stamp.apply(clean)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# time_stamp              0
# gender                  0
# age                     0
# course                  0
# current_year            0
# cgpa                    0
# married                 0
# depression              0
# anxiety                 0
# panic_attack            0
# specialist_treatment    0
# month_filled            0
# dtype: int64

# %%
#type cast the age column to integer

df['age'] = df.age.astype('int')

# %%
#Edit the courses column

def clean_column(word):
    return word.strip().lower()

# %%
df['course'] = df['course'].apply(clean_column)

# %%
#function to edit the course column

def clean_course(course):
    if course == 'engin' or course == 'engine':
        return "engineering"
    elif course == "mathemathics":
        return "mathematics"
    else:
        return course

# %%
df['course'] = df['course'].apply(clean_course)

# %%
df.course.value_counts().keys()
# Out:
# Index(['engineering', 'bcs', 'bit', 'koe', 'biomedical science', 'psychology',
#        'benl', 'pendidikan islam', 'laws', 'islamic education', 'kirkhs',
#        'diploma tesl', 'kop', 'econs', 'mhsc', 'malcom', 'human sciences',
#        'fiqh fatwa', 'fiqh', 'biotechnology', 'cts', 'diploma nursing',
#        'radiography', 'communication', 'usuluddin', 'it', 'ala', 'taasl',
#        'law', 'business administration', 'banking studies', 'marine science',
#        'enm', 'accounting', 'kenms', 'irkhs', 'human resources', 'mathematics',
#        'nursing'],
#       dtype='object')

# %%
df.course.value_counts()
# Out:
# engineering                20
# bcs                        18
# bit                         9
# koe                         6
# biomedical science          4
# psychology                  3
# benl                        3
# pendidikan islam            3
# laws                        2
# islamic education           2
# kirkhs                      2
# diploma tesl                1
# kop                         1
# econs                       1
# mhsc                        1
# malcom                      1
# human sciences              1
# fiqh fatwa                  1
# fiqh                        1
# biotechnology               1
# cts                         1
# diploma nursing             1
# radiography                 1
# communication               1
# usuluddin                   1
# it                          1
# ala                         1
# taasl                       1
# law                         1
# business administration     1
# banking studies             1
# ...

# %%
df['current_year'] = df['current_year'].apply(clean_column)

# %%
#cleaning the cgpa column

df['cgpa'] = df['cgpa'].str.strip()

# %%
df.columns
# Out:
# Index(['time_stamp', 'gender', 'age', 'course', 'current_year', 'cgpa',
#        'married', 'depression', 'anxiety', 'panic_attack',
#        'specialist_treatment', 'month_filled'],
#       dtype='object')

# %% [markdown]
# # 💥 Exploratory Data Analysis (EDA)

# %%
df
# Out:
#     time_stamp  gender  age              course current_year         cgpa  \
# 0   2020-08-07  Female   18         engineering       year 1  3.00 - 3.49
# 1   2020-08-07    Male   21   islamic education       year 2  3.00 - 3.49
# 2   2020-08-07    Male   19                 bit       year 1  3.00 - 3.49
# 3   2020-08-07  Female   22                laws       year 3  3.00 - 3.49
# 4   2020-08-07    Male   23         mathematics       year 4  3.00 - 3.49
# ..         ...     ...  ...                 ...          ...          ...
# 96  2020-07-13  Female   21                 bcs       year 1  3.50 - 4.00
# 97  2020-07-13    Male   18         engineering       year 2  3.00 - 3.49
# 98  2020-07-13  Female   19             nursing       year 3  3.50 - 4.00
# 99  2020-07-13  Female   23    pendidikan islam       year 4  3.50 - 4.00
# 100 2020-07-18    Male   20  biomedical science       year 2  3.00 - 3.49
#
#     married depression anxiety panic_attack specialist_treatment month_filled
# ...

# %%
#Analysing month for submitting responses

y = df['month_filled'].value_counts()
y
# Out:
# August       72
# July         23
# September     5
# Name: month_filled, dtype: int64

# %%
mylabel = df['month_filled'].value_counts().keys()
myexplode = [0.15,0,0]

# %%
#plot of the busiest month

sns.set()
plt.figure(figsize=(10,8))
plt.pie(y,labels=mylabel,explode = myexplode,autopct="%1.1f%%",pctdistance=0.5,shadow=True)
plt.title("Busiest Month for Responses",fontweight="bold",fontsize="25",loc="center")
plt.legend(title='Month:',loc ="best")
plt.show()

# %% [markdown]
# > Analyzing the plot reveals a prominent trend: August emerges as the busiest month for responses, capturing approximately 72% of the entire dataset. Following closely are July and September, with September registering the least activity.
# >
# > With this insight, the next question to explore is: which gender contributed the most responses?

# %% [markdown]
# ## Gender with Most Response Contribution

# %%
#plot of gender by year of study

sns.set_style('darkgrid')
sns.countplot(x = df.gender,hue = df.current_year,edgecolor="black")
plt.title("Gender by Year of Study",fontweight="bold",fontsize="15",loc="center")
plt.show()

# %% [markdown]
# > Upon analyzing the gender-based contributions to responses, it becomes evident that among the Year 1 students, females made a more substantial contribution compared to their male counterparts.
# >
# >Specifically, Year 1 female students emerged as the leading contributors. On the other hand, among the male respondents, it was the second-year students who made the most significant contribution.

# %%
#count of the age column

df.age.value_counts()
# Out:
# 18    32
# 24    23
# 19    21
# 23    13
# 20     6
# 21     3
# 22     2
# Name: age, dtype: int64

# %%
#distribution of the age

sns.displot(x = df.age,edgecolor="black")
plt.title('Distribution of Ages',fontweight="bold",fontsize="17",loc="center")
plt.show()

# %% [markdown]
# Let's delve into the main reason for our analysis, of which student has the highest cgpa and also the student with the least cgpa and also what could be the reason

# %%
#count of the cgpa

y = df.cgpa.value_counts()
y
# Out:
# 3.50 - 4.00    48
# 3.00 - 3.49    43
# 2.50 - 2.99     4
# 0 - 1.99        3
# 2.00 - 2.49     2
# Name: cgpa, dtype: int64

# %%
mylabel = df.cgpa.value_counts().keys()
mylabel
# Out:
# Index(['3.50 - 4.00', '3.00 - 3.49', '2.50 - 2.99', '0 - 1.99', '2.00 - 2.49'], dtype='object')

# %%
myexplode = [0.1,0,0,0,0]

# %%
#cgpa distribution plot

plt.figure(figsize=(10,7))
plt.pie(y,labels=mylabel,explode = myexplode,autopct="%1.1f%%",pctdistance=0.5,shadow=True)
plt.title("CGPA Distribution",fontweight="bold",fontsize="25",loc="center")
plt.legend(title='CGPA:',loc ="best")
plt.show()

# %% [markdown]
# > The CGPA ranges can be interpreted as follows:
# >
# > - **3.50 - 4.00:** Typically corresponds to "First Class," representing excellent academic performance.
# > - **3.00 - 3.49:** Falls within the "Second Class Upper" classification, signifying a very commendable level of academic achievement.
# > - **2.50 - 2.99:** Often categorized as "Second Class Lower," reflecting a satisfactory level of academic performance.
# > - **2.00 - 2.49:** Generally considered a "Third Class," indicating a passable level of academic achievement.
# > - **0.00 - 1.99:** This range often represents a "Fail" or "Incomplete," suggesting performance below the passing threshold.
# >
# > In analyzing our dataset, it becomes apparent that 48% of the entries pertain to First Class students, indicating a higher submission rate from this category. Following closely, the Second Class Upper category accounts for 43% of the dataset. The Third Class category, the smallest proportion, is represented by only around 2% of the dataset. Additionally, about 3% of the dataset consists of students who failed.

# %% [markdown]
# # First Class Analysis

# %%
#filter of first class student

excel = df[df['cgpa'] == '3.50 - 4.00']

# %%
#five samples from the dataset

excel.sample(5)
# Out:
#    time_stamp  gender  age         course current_year         cgpa married  \
# 29 2020-08-07  Female   24            bcs       year 4  3.50 - 4.00      No
# 80 2020-07-13  Female   24  communication       year 2  3.50 - 4.00     Yes
# 62 2020-08-07  Female   18            cts       year 1  3.50 - 4.00      No
# 45 2020-08-07    Male   18            bcs       year 1  3.50 - 4.00      No
# 56 2020-08-07    Male   23         kirkhs       year 3  3.50 - 4.00      No
#
#    depression anxiety panic_attack specialist_treatment month_filled
# 29         No      No           No                   No       August
# 80        Yes     Yes          Yes                   No         July
# 62         No      No          Yes                   No       August
# 45         No     Yes          Yes                   No       August
# 56         No      No           No                   No       August

# %%
#first 10 unique values in the course column of the first class dataset

excel.course.value_counts().keys()[:10]
# Out:
# Index(['bcs', 'engineering', 'psychology', 'bit', 'kirkhs', 'pendidikan islam',
#        'malcom', 'islamic education', 'diploma tesl', 'diploma nursing'],
#       dtype='object')

# %%
#course

excel.course.value_counts()
# Out:
# bcs                  14
# engineering           9
# psychology            3
# bit                   3
# kirkhs                2
# pendidikan islam      2
# malcom                1
# islamic education     1
# diploma tesl          1
# diploma nursing       1
# communication         1
# koe                   1
# laws                  1
# taasl                 1
# econs                 1
# cts                   1
# banking studies       1
# marine science        1
# kenms                 1
# irkhs                 1
# nursing               1
# Name: course, dtype: int64

# %%
# plot of top 10 courses

plt.figure(figsize=(15,10))
sns.set_style('darkgrid')
sns.barplot(x = excel.course.value_counts().keys()[:10],y = excel.course.value_counts().head(10),edgecolor="black")
plt.title("Distribution of Top 10 First Class Course",fontweight="bold",fontsize="19",loc="center")
plt.show()

# %% [markdown]
# >There are more than 10 courses that have first classes. Specifically, in the BCS program, there are 14 students who achieved a first class. Similarly, in engineering, there are 9 first-class students, while psychology and BIT have 3 each.
# >
# >Focusing on these first four courses is beneficial for further analysis as they encompass a significant portion of our data.

# %%
#The first two course

top4 = excel[(excel.course == 'engineering') | (excel.course =='bcs') | (excel.course =='psychology') | (excel.course =='bit')]
top4
# Out:
#    time_stamp  gender  age       course current_year         cgpa married  \
# 5  2020-08-07    Male   19  engineering       year 2  3.50 - 4.00      No
# 7  2020-08-07  Female   18          bcs       year 1  3.50 - 4.00      No
# 10 2020-08-07  Female   20   psychology       year 1  3.50 - 4.00      No
# 11 2020-08-07  Female   24  engineering       year 3  3.50 - 4.00     Yes
# 15 2020-08-07    Male   24          bcs       year 3  3.50 - 4.00      No
# 18 2020-08-07  Female   20          bit       year 2  3.50 - 4.00      No
# 22 2020-08-07  Female   24          bcs       year 1  3.50 - 4.00      No
# 24 2020-08-07  Female   23          bcs       year 3  3.50 - 4.00      No
# 26 2020-08-07  Female   19  engineering       year 1  3.50 - 4.00      No
# 28 2020-08-07  Female   24          bit       year 3  3.50 - 4.00     Yes
# 29 2020-08-07  Female   24          bcs       year 4  3.50 - 4.00      No
# 32 2020-08-07    Male   19          bcs       year 1  3.50 - 4.00      No
# ...

# %%
sns.set_style('darkgrid')
sns.countplot(x = top4.course,hue = excel.current_year,edgecolor="black")
plt.title("Course by Year of Study",fontweight="bold",fontsize="15",loc="center")
plt.show()

# %% [markdown]
# >Analyzing grades of engineering, psychology and computer science students shows something interesting: many get the highest marks (first-class distinctions) mostly in their first year. This pattern suggests that doing well early on plays a big role in how these students stand out.

# %%
year1 = top4[(top4.current_year == "year 1" )]

# %%
year1
# Out:
#    time_stamp  gender  age       course current_year         cgpa married  \
# 7  2020-08-07  Female   18          bcs       year 1  3.50 - 4.00      No
# 10 2020-08-07  Female   20   psychology       year 1  3.50 - 4.00      No
# 22 2020-08-07  Female   24          bcs       year 1  3.50 - 4.00      No
# 26 2020-08-07  Female   19  engineering       year 1  3.50 - 4.00      No
# 32 2020-08-07    Male   19          bcs       year 1  3.50 - 4.00      No
# 45 2020-08-07    Male   18          bcs       year 1  3.50 - 4.00      No
# 46 2020-08-07  Female   19  engineering       year 1  3.50 - 4.00      No
# 54 2020-08-07  Female   19          bcs       year 1  3.50 - 4.00      No
# 58 2020-08-07  Female   18          bcs       year 1  3.50 - 4.00      No
# 61 2020-08-07  Female   19          bcs       year 1  3.50 - 4.00      No
# 63 2020-08-07  Female   24  engineering       year 1  3.50 - 4.00      No
# 64 2020-08-07  Female   24  engineering       year 1  3.50 - 4.00      No
# ...

# %%
x = year1.married.value_counts()
print(x)
# Out:
# No    15
# Name: married, dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.pie(x,labels=x.keys(),autopct="%1.1f%%",pctdistance=0.5,shadow=True)
plt.title("Married Students",fontweight="bold",fontsize="25",loc="center")
plt.legend(title='married:',loc ="best")
plt.show()

# %% [markdown]
# > Out of the 15 first-class Year 1 students, none of them, i.e., 100 percent, are not married. This reflects a dedicated approach to education, allowing students to concentrate fully on their studies and potentially achieve higher academic performance.

# %%
x = year1.depression.value_counts()
print(x)
# Out:
# No     12
# Yes     3
# Name: depression, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.pie(x,labels=x.keys(),autopct="%0.1f%%",textprops={'color': 'black',"fontsize":13},wedgeprops={"width":0.8},shadow=True,explode=[0,0.3])
plt.title("Depression",fontweight="bold",fontsize="25",loc="center")
plt.show()

# %%
year1[year1.depression == "Yes"]
# Out:
#    time_stamp  gender  age      course current_year         cgpa married  \
# 54 2020-08-07  Female   19         bcs       year 1  3.50 - 4.00      No
# 85 2020-07-13  Female   18  psychology       year 1  3.50 - 4.00      No
# 87 2020-07-13  Female   18  psychology       year 1  3.50 - 4.00      No
#
#    depression anxiety panic_attack specialist_treatment month_filled
# 54        Yes      No          Yes                  Yes       August
# 85        Yes     Yes           No                  Yes         July
# 87        Yes     Yes          Yes                   No         July

# %% [markdown]
# >80% of our dataset shows no signs of depression, while approximately 20% (3 individuals) are experiencing depression. Interestingly, all three of the students who are depressed are female.
# >
# >Additionally, two of them are currently undergoing special treatment, suggesting a proactive approach to addressing mental health challenges within our dataset.

# %%
x1 = year1.anxiety.value_counts()
print(x1)
print()
x2 = year1.panic_attack.value_counts()
print(x2)
# Out:
# No     9
# Yes    6
# Name: anxiety, dtype: int64
#
# No     10
# Yes     5
# Name: panic_attack, dtype: int64

# %%
#figure size
plt.figure(figsize=(25,10))

#type1's plot

#create subplot
plt.subplot(1,2,1)
plt.pie(x1,labels=x1.keys(),autopct="%0.1f%%",textprops={'color': 'black',"fontsize":13},startangle=20,wedgeprops={"width":0.9},colors=['orange','green'],shadow=True,explode=[0,0.3])
plt.title("Anxiety",fontweight="bold",fontsize="25",loc="center")

#type2's plot
plt.subplot(1,2,2)
plt.pie(x2,labels=x2.keys(),autopct="%0.1f%%",textprops={'color': 'black',"fontsize":13},startangle=30,wedgeprops={"width":0.9},colors=['orange','green'],shadow=True,explode=[0,0.3])
plt.title("Panic Attack",fontweight="bold",fontsize="25",loc="center")
plt.suptitle("Anxiety and Panic Attack",fontweight="bold",fontsize="40")

#display plot
plt.show()

# %% [markdown]
# >For Year 1 students, 60% are not dealing with depression, showing a majority in good mental health. Also, about 66.7% of students don't experience panic attacks, indicating that most are not facing this issue.
# >
# >Overall, these numbers suggest that a significant portion of Year 1 students have positive mental health without depression or panic attacks.

# %%
x = year1.specialist_treatment.value_counts()
print(x)
# Out:
# No     13
# Yes     2
# Name: specialist_treatment, dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.pie(x,labels=x.keys(),autopct="%0.1f%%",textprops={'color': 'black',"fontsize":13},shadow=True,wedgeprops={"width":0.9},explode=[0,0.3])
plt.title("Specialist Treatment",fontweight="bold",fontsize="22",loc="center")
plt.show()

# %%
year1[year1.specialist_treatment == "Yes"]
# Out:
#    time_stamp  gender  age      course current_year         cgpa married  \
# 54 2020-08-07  Female   19         bcs       year 1  3.50 - 4.00      No
# 85 2020-07-13  Female   18  psychology       year 1  3.50 - 4.00      No
#
#    depression anxiety panic_attack specialist_treatment month_filled
# 54        Yes      No          Yes                  Yes       August
# 85        Yes     Yes           No                  Yes         July

# %% [markdown]
# >Of the students, 86.7% haven't received special treatment, demonstrating a large majority without such interventions. However, there is a record of 2 individuals (13.3%) who have undergone special treatment. This information suggests that while the majority do not require special interventions, a small percentage has sought or required additional support.

# %% [markdown]
# # Conclusion
#
# In summary, focusing on good grades is crucial for Year 1 students. It's beneficial to avoid getting into relationships or marriage during this time, as shown by the data on first-class students.
#
# Moreover, prioritizing health, both physical and mental, is also key. Students who take care of their well-being and seek support when needed are better set up for success. Therefore, a balanced approach that includes academic dedication, thoughtful relationship choices, and health consciousness is essential for thriving in school.
